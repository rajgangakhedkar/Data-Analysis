# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
import ast

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\rajga\anaconda3\lib\site-packages (1.7.4.5)
# Requirement already satisfied: bleach in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: charset-normalizer in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (3.3.2)
# Requirement already satisfied: idna in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (3.7)
# Requirement already satisfied: protobuf in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (4.25.3)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (75.1.0)
# Requirement already satisfied: six>=1.10 in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: text-unidecode in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (4.66.5)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (2.2.3)
# Requirement already satisfied: webencodings in c:\users\rajga\anaconda3\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: packaging in c:\users\rajga\anaconda3\lib\site-packages (from bleach->kaggle) (24.1)
# Requirement already satisfied: colorama in c:\users\rajga\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)

# %%
import zipfile

# %%
with zipfile.ZipFile("C:/Users/rajga/Desktop/python/VSCODE/USaccidentEDA/usaccidents.zip") as zef:
    zef.extractall()

# %%
df = pd.read_csv("C:/Users/rajga/US_Accidents_March23.csv")

# %%
df
# Out:
#                 ID   Source  Severity           Start_Time  \
# 0              A-1  Source2         3  2016-02-08 05:46:00
# 1              A-2  Source2         2  2016-02-08 06:07:59
# 2              A-3  Source2         2  2016-02-08 06:49:27
# 3              A-4  Source2         3  2016-02-08 07:23:34
# 4              A-5  Source2         2  2016-02-08 07:39:07
# ...            ...      ...       ...                  ...
# 7728389  A-7777757  Source1         2  2019-08-23 18:03:25
# 7728390  A-7777758  Source1         2  2019-08-23 19:11:30
# 7728391  A-7777759  Source1         2  2019-08-23 19:00:21
# 7728392  A-7777760  Source1         2  2019-08-23 19:00:21
# 7728393  A-7777761  Source1         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN
# 1        2016-02-08 06:37:59  39.928059  -82.831184       NaN        NaN
# 2        2016-02-08 07:19:27  39.063148  -84.032608       NaN        NaN
# 3        2016-02-08 07:53:34  39.747753  -84.205582       NaN        NaN
# 4        2016-02-08 08:09:07  39.627781  -84.188354       NaN        NaN
# ...                      ...        ...         ...       ...        ...
# 7728389  2019-08-23 18:32:01  34.002480 -117.379360  33.99888 -117.37094
# 7728390  2019-08-23 19:38:23  32.766960 -117.148060  32.76555 -117.15363
# 7728391  2019-08-23 19:28:49  33.775450 -117.847790  33.77740 -117.85727
# 7728392  2019-08-23 19:29:42  33.992460 -118.403020  33.98311 -118.39565
# 7728393  2019-08-23 19:21:31  34.133930 -117.230920  34.13736 -117.23934
#
#          Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 0               0.010  ...      False   False  False           False
# 1               0.010  ...      False   False  False           False
# 2               0.010  ...      False   False  False           False
# 3               0.010  ...      False   False  False           False
# 4               0.010  ...      False   False  False           False
# ...               ...  ...        ...     ...    ...             ...
# 7728389         0.543  ...      False   False  False           False
# 7728390         0.338  ...      False   False  False           False
# 7728391         0.561  ...      False   False  False           False
# 7728392         0.772  ...      False   False  False           False
# 7728393         0.537  ...      False   False  False           False
#
#         Traffic_Signal Turning_Loop Sunrise_Sunset Civil_Twilight  \
# 0                False        False          Night          Night
# 1                False        False          Night          Night
# 2                 True        False          Night          Night
# 3                False        False          Night            Day
# 4                 True        False            Day            Day
# ...                ...          ...            ...            ...
# 7728389          False        False            Day            Day
# 7728390          False        False            Day            Day
# 7728391          False        False            Day            Day
# 7728392          False        False            Day            Day
# 7728393          False        False            Day            Day
#
#         Nautical_Twilight Astronomical_Twilight
# 0                   Night                 Night
# 1                   Night                   Day
# 2                     Day                   Day
# 3                     Day                   Day
# 4                     Day                   Day
# ...                   ...                   ...
# 7728389               Day                   Day
# 7728390               Day                   Day
# 7728391               Day                   Day
# 7728392               Day                   Day
# 7728393               Day                   Day
#
# [7728394 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
#  21  Wind_Chill(F)          float64
#  22  Humidity(%)            float64
#  23  Pressure(in)           float64
#  24  Visibility(mi)         float64
#  25  Wind_Direction         object
#  26  Wind_Speed(mph)        float64
#  27  Precipitation(in)      float64
#  28  Weather_Condition      object
#  29  Amenity                bool
#  30  Bump                   bool
#  31  Crossing               bool
#  32  Give_Way               bool
#  33  Junction               bool
#  34  No_Exit                bool
#  35  Railway                bool
#  36  Roundabout             bool
#  37  Station                bool
#  38  Stop                   bool
#  39  Traffic_Calming        bool
#  40  Traffic_Signal         bool
#  41  Turning_Loop           bool
#  42  Sunrise_Sunset         object
#  43  Civil_Twilight         object
#  44  Nautical_Twilight      object
#  45  Astronomical_Twilight  object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 2.0+ GB

# %% [markdown]
# **Finding Nulls

# %%
df.isnull().sum()   #to check nulls
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# Weather_Condition         173459
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset             23246
# Civil_Twilight             23246
# Nautical_Twilight          23246
# Astronomical_Twilight      23246
# dtype: int64

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# min    0.000000e+00   -8.900000e+01  -8.900000e+01  1.000000e+00
# 25%    0.000000e+00    4.900000e+01   4.300000e+01  4.800000e+01
# 50%    3.000000e-02    6.400000e+01   6.200000e+01  6.700000e+01
# 75%    4.640000e-01    7.600000e+01   7.500000e+01  8.400000e+01
# max    4.417500e+02    2.070000e+02   2.070000e+02  1.000000e+02
#
#        Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count  7.587715e+06    7.551296e+06     7.157161e+06       5.524808e+06
# mean   2.953899e+01    9.090376e+00     7.685490e+00       8.407210e-03
# std    1.006190e+00    2.688316e+00     5.424983e+00       1.102246e-01
# min    0.000000e+00    0.000000e+00     0.000000e+00       0.000000e+00
# 25%    2.937000e+01    1.000000e+01     4.600000e+00       0.000000e+00
# 50%    2.986000e+01    1.000000e+01     7.000000e+00       0.000000e+00
# 75%    3.003000e+01    1.000000e+01     1.040000e+01       0.000000e+00
# max    5.863000e+01    1.400000e+02     1.087000e+03       3.647000e+01

# %%
missing_data_percent = df.isnull().sum().sort_values(ascending=False)*100/len(df)

# %%
missing_data_percent=missing_data_percent[missing_data_percent.values >0]

# %%
missing_data_percent
# Out:
# End_Lat                  44.029355
# End_Lng                  44.029355
# Precipitation(in)        28.512858
# Wind_Chill(F)            25.865904
# Wind_Speed(mph)           7.391355
# Visibility(mi)            2.291524
# Wind_Direction            2.267043
# Humidity(%)               2.253301
# Weather_Condition         2.244438
# Temperature(F)            2.120143
# Pressure(in)              1.820288
# Weather_Timestamp         1.555666
# Nautical_Twilight         0.300787
# Civil_Twilight            0.300787
# Sunrise_Sunset            0.300787
# Astronomical_Twilight     0.300787
# Airport_Code              0.292881
# Street                    0.140637
# Timezone                  0.101030
# Zipcode                   0.024779
# City                      0.003274
# Description               0.000065
# dtype: float64

# %%
missing_data_percent.plot(kind='barh')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
unq_city=df['City'].unique()

# %%
cities_by_accident = df['City'].value_counts().head(20)
cities_by_accident
# Out:
# City
# Miami            186917
# Houston          169609
# Los Angeles      156491
# Charlotte        138652
# Dallas           130939
# Orlando          109733
# Austin            97359
# Raleigh           86079
# Nashville         72930
# Baton Rouge       71588
# Atlanta           68186
# Sacramento        66264
# San Diego         55504
# Phoenix           53974
# Minneapolis       51488
# Richmond          48845
# Oklahoma City     46092
# Jacksonville      42447
# Tucson            39304
# Columbia          38178
# Name: count, dtype: int64

# %%
cities_by_accident.plot(kind='barh')
plt.show()

# %%
City_state_by_accidents=df.groupby(by=["City","State"]).agg("size").sort_values(ascending=False)

# %%
City_state_by_accidents.head(100)
# Out:
# City         State
# Miami        FL       186768
# Houston      TX       169428
# Los Angeles  CA       156491
# Charlotte    NC       138345
# Dallas       TX       130303
#                        ...
# Fremont      CA         9664
# Buffalo      NY         9574
# Tempe        AZ         9531
# Gardena      CA         9479
# Ocala        FL         9456
# Length: 100, dtype: int64

# %%
State_acc=City_state_by_accidents

# %%
State_acc=State_acc.reset_index(name="Count")

# %%
State_acc=State_acc.drop(columns="City")

# %%
State_acc=State_acc.head(5)

# %%
plt.bar(State_acc.State, State_acc.Count)
plt.title("Top 5 States with most accidents")
plt.xlabel("States")
plt.ylabel("Count of accidents")
# Out:
# Text(0, 0.5, 'Count of accidents')

# %%
import seaborn as sns

# %%
sns.set_style("darkgrid")
city_acc= df['City'].value_counts()
sns.distplot(city_acc)
# Out:
# C:\Users\rajga\AppData\Local\Temp\ipykernel_14372\2700316380.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(city_acc)
# <Axes: xlabel='count', ylabel='Density'>

# %%
high_accident_city = city_acc[city_acc>=1000] 
low_accident_city = city_acc[city_acc<1000]

# %%
len(high_accident_city)/len(unq_city)
# Out:
# 0.08904159660793917

# %%
sns.histplot(low_accident_city,log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
#over 1000 cities has reported just 1 accident(need to investigate)
city_acc[city_acc==1]
# Out:
# City
# Lake Andes                      1
# Catoctin                        1
# Duck Hill                       1
# Westbrookville                  1
# Saint Croix                     1
#                                ..
# Benkelman                       1
# Old Appleton                    1
# Wildrose                        1
# Mc Nabb                         1
# American Fork-Pleasant Grove    1
# Name: count, Length: 1023, dtype: int64

# %% [markdown]
# ### Start Time

# %%
type(df.Start_Time[0])
# Out:
# str

# %%
df.Start_Time= pd.to_datetime(df.Start_Time,format='mixed')

# %%
df.Start_Time
# Out:
# 0         2016-02-08 05:46:00
# 1         2016-02-08 06:07:59
# 2         2016-02-08 06:49:27
# 3         2016-02-08 07:23:34
# 4         2016-02-08 07:39:07
#                   ...
# 7728389   2019-08-23 18:03:25
# 7728390   2019-08-23 19:11:30
# 7728391   2019-08-23 19:00:21
# 7728392   2019-08-23 19:00:21
# 7728393   2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: datetime64[ns]

# %%
df['Start_Time'].dt.hour.value_counts().sort_index().plot(kind='barh')
# Out:
# <Axes: ylabel='Start_Time'>

# %%
sns.distplot(df['Start_Time'].dt.hour,bins=24)
# Out:
# C:\Users\rajga\AppData\Local\Temp\ipykernel_14372\349827518.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Start_Time'].dt.hour,bins=24)
# <Axes: xlabel='Start_Time', ylabel='Density'>

# %%
acc_time_hr_per=(df['Start_Time'].dt.hour.value_counts()/len(df)*100)

# %%
plt.bar(acc_time_hr_per.index,acc_time_hr_per.values)
plt.xlabel("Timing Hr")
plt.ylabel("Accident percentage")
# Out:
# Text(0, 0.5, 'Accident percentage')

# %% [markdown]
# * we can see from above that highest level of accidents occur around 6am to 10pm as it is office timing and it again rises around 3pm to 6pm.

# %%
day_lables=['Mon','Tues','Wed','Thur','Fri','Sat','Sun']
acc_dayofweek=df['Start_Time'].dt.dayofweek.value_counts().sort_values(ascending=False)
plt.title("Total accidents by time for all days")
plt.bar(acc_dayofweek.index,acc_dayofweek.values)
plt.xticks(ticks=range(7), labels=day_lables)
plt.show()

# %% [markdown]
# * we can see max number of accidents occur on week days due to offices and schools, where as weekends has less accidents as no one is in rush

# %%
data_of_weekend=df[(df['Start_Time'].dt.dayofweek==6) | (df['Start_Time'].dt.dayofweek== 5)]

# %%
weekend_timings=data_of_weekend['Start_Time'].dt.hour.value_counts().sort_index()

# %%
weekend_timings
# Out:
# Start_Time
# 0     36799
# 1     33209
# 2     34382
# 3     28196
# 4     27429
# 5     28134
# 6     34392
# 7     39925
# 8     41536
# 9     49579
# 10    59633
# 11    69479
# 12    74529
# 13    78811
# 14    80285
# 15    75704
# 16    72662
# 17    67508
# 18    64482
# 19    56609
# 20    51166
# 21    49359
# 22    42506
# 23    35113
# Name: count, dtype: int64

# %%
plt.bar(weekend_timings.index,weekend_timings.values)
plt.title("Total accidents by time on Saturday and Sunday")
plt.xlabel("Timings")
plt.ylabel("Number of accidents")
# Out:
# Text(0, 0.5, 'Number of accidents')

# %% [markdown]
# * above we can see the graph for accidents caused on weekend ie Sunday and Saturday. We can conlcude maximum accidents occur during mid aftertoon

# %%
data_of_weekday=df[(df['Start_Time'].dt.dayofweek==0)]

# %%
week_day_timings=data_of_weekday['Start_Time'].dt.hour.value_counts().sort_index()

# %%
plt.bar(week_day_timings.index,week_day_timings.values)
plt.title("Total accidents by time on Monday")
plt.xlabel("Timings")
plt.ylabel("Number of accidents")
# Out:
# Text(0, 0.5, 'Number of accidents')

# %% [markdown]
# * above we can see the accidents occured on Monday, we can conclude that maximum accidents occur during office timings

# %%
plt.bar(data_of_weekday['Start_Time'].dt.month.value_counts().sort_index().index,
        data_of_weekday['Start_Time'].dt.month.value_counts().sort_index().values)

plt.title("Total number of accidents by Months")
plt.xlabel("Month number")
plt.ylabel("Number of accidents")
# Out:
# Text(0, 0.5, 'Number of accidents')

# %% [markdown]
# * as we have data from feb 2016 to march 2023, we can see there are more accidents from nov to jan. Due to missing data from April 2023 to Dec 2023 we can predecit the amount of accidents would be highest in November and December

# %%
plt.bar(data_of_weekday['Start_Time'].dt.year.value_counts().sort_index().index,
        data_of_weekday['Start_Time'].dt.year.value_counts().sort_index().values)
plt.title("Total number of accidents by Year")
plt.xlabel("Year")
plt.ylabel("Number of accidents")
# Out:
# Text(0, 0.5, 'Number of accidents')

# %%
df['Source'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
sample_df = df.sample(int(0.1 * len(df)))

# %%
plt.scatter(x=sample_df.Start_Lng, y=sample_df.Start_Lat, s=3)

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\rajga\anaconda3\lib\site-packages (0.19.6)
# Requirement already satisfied: branca>=0.6.0 in c:\users\rajga\anaconda3\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\rajga\anaconda3\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\rajga\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\rajga\anaconda3\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\rajga\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rajga\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rajga\anaconda3\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajga\anaconda3\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rajga\anaconda3\lib\site-packages (from requests->folium) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajga\anaconda3\lib\site-packages (from requests->folium) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
from folium.plugins import HeatMap

zip(list(df.Start_Lat), list(df.Start_Lng))

# %%
sample2 = df.sample(int(len(df) * 0.01))
map=folium.Map()
HeatMap(zip(list(sample2.Start_Lat), list(sample2.Start_Lng))).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed4ed12eff1e7b78f8bec92295cef103 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed4ed12eff1e7b78f8bec92295cef103&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed4ed12eff1e7b78f8bec92295cef103 = L.map(
#                 &quot;map_ed4ed12eff1e7b78f8bec92295cef103&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b865270edd32b22c1d6fb6284ded74c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b865270edd32b22c1d6fb6284ded74c5.addTo(map_ed4ed12eff1e7b78f8bec92295cef103);
#
#
#             var heat_map_96db190466e4e06f35182db15adfec33 = L.heatLayer(
#                 [[42.985451, -83.92865], [33.82927536948285, -117.46355652753132], [41.424789, -81.562164], [30.748224, -85.38391899999998], [40.08178, -78.885906], [42.505507, -83.758166], [33.804946, -118.351035], [38.011894, -121.866753], [37.308701, -121.96373], [35.396971, -81.926614], [25.913296, -80.32504300000002], [30.39216, -83.066244], [27.916626, -82.783363], [44.97091412522806, -93.44894528344416], [25.762934, -80.396821], [44.980751, -93.244141], [36.07315300000001, -85.198453], [42.41299, -83.08331], [34.064339000000004, -118.004738], [40.615345, -80.095299], [32.30069518, -96.57603621], [34.046803000000004, -117.918418], [33.7914, -117.87991], [34.93943095, -78.91890407], [37.551864, -77.45230600000002], [33.95285010321639, -80.96435666045683], [37.555279, -77.446859], [41.417051, -73.419409], [37.143716, -121.984761], [30.426279, -97.675362], [42.985653000000006, -78.912498], [37.4373, -77.60049000000002], [34.205166, -118.983696], [33.971379, -118.081035], [30.27306, -97.798477], [34.28108811362132, -118.40033411923216], [43.014648, -83.517563], [25.777796, -80.321945], [35.79825200000001, -78.487503], [37.08882451039749, -76.4589536186387], [40.611958, -73.968149], [44.834702, -93.55265], [33.922327, -118.104368], [32.744652, -83.718712], [38.840643, -84.616037], [43.153603, -77.619789], [34.54287, -117.983734], [33.370274, -112.169075], [40.09422898273423, -74.09371733630135], [34.275841, -119.287926], [32.75991, -97.1164], [29.771896, -95.345732], [33.917651, -118.273851], [38.84702100000001, -77.120538], [28.458104, -81.49140799999998], [39.222481, -76.72069499999998], [34.254146, -118.324332], [37.779709, -121.31546000000002], [32.827653000000005, -96.828865], [33.537987, -112.22038700000002], [29.840494, -95.545166], [36.114624, -86.72440300000002], [30.2997, -97.689354], [40.987408, -73.670479], [42.04391598681429, -83.28009009321555], [32.809486, -96.820236], [40.755287, -73.995835], [40.993119, -73.66080799999997], [33.0482, -116.85785], [40.31181, -76.90038299999998], [35.241507, -80.849849], [36.074089, -120.093163], [40.588, -111.90253], [42.950584, -78.703362], [29.758608, -95.486191], [28.045953000000004, -81.922302], [29.72373, -95.386124], [30.22649, -95.45776], [28.22436, -82.72313], [35.305782, -80.749741], [45.58352, -122.76803999999998], [33.74688, -118.29218], [33.77453, -118.07979], [33.901691, -84.473511], [38.671844, -77.246376], [36.923611, -78.08918800000002], [37.794624, -122.20623799999998], [44.883553000000006, -93.295952], [32.1231, -83.760849], [37.823395, -122.316414], [32.920590000000004, -96.75061], [37.787697, -122.197998], [42.312309, -71.055008], [33.970802, -118.280608], [26.087816, -80.363686], [25.868401, -80.208908], [39.828552, -75.432106], [35.8634, -78.598389], [41.24880200000001, -96.05262], [26.50066, -81.79409799999998], [28.146066, -81.464409], [32.646294, -97.185364], [40.163742, -76.151199], [33.181758, -117.326807], [35.020813000000004, -90.000313], [30.284614, -97.71713], [38.24649, -121.431221], [34.150494, -117.478616], [35.23642, -80.70195], [25.889471, -80.162038], [30.190822, -81.67931999999998], [32.221151, -110.969316], [25.692903, -80.378017], [34.13517, -80.963799], [34.083685, -117.693902], [34.909037, -79.686408], [30.249918, -81.551762], [25.89854, -80.351318], [34.303248, -118.479759], [36.977736, -76.499472], [28.346506, -81.605453], [25.840026, -80.31226600000002], [33.819342, -84.494816], [39.096176, -94.590454], [45.82127, -119.54931299999998], [38.34056, -77.49154899999998], [30.381201, -97.685143], [32.894958, -96.846789], [34.440231, -117.642227], [45.49363, -122.56538], [35.001968, -80.732559], [32.92585, -80.0815
